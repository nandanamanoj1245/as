# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r"C:/Users/User/Downloads/loan_dataset.csv")

# %%
data.head()
# Out:
#         loan_id source       financial_institution  interest_rate  \
# 0  268055008619      Z  Turner, Baldwin and Rhodes          4.250
# 1  672831657627      Y  Swanson, Newton and Miller          4.875
# 2  742515242108      Z              Thornton-Davis          3.250
# 3  601385667462      X                       OTHER          4.750
# 4  273870029961      X                       OTHER          4.750
#
#    unpaid_principal_bal  loan_term origination_date first_payment_date  \
# 0                214000        360       2012-03-01            05/2012
# 1                144000        360       2012-01-01            03/2012
# 2                366000        180       2012-01-01            03/2012
# 3                135000        360       2012-02-01            04/2012
# 4                124000        360       2012-02-01            04/2012
#
#    loan_to_value  number_of_borrowers  ...  m4  m5 m6  m7  m8  m9  m10  m11  \
# ...

# %%
data.shape
# Out:
# (116058, 29)

# %%
data.isna().sum()
# Out:
# loan_id                     0
# source                      0
# financial_institution       0
# interest_rate               0
# unpaid_principal_bal        0
# loan_term                   0
# origination_date            0
# first_payment_date          0
# loan_to_value               0
# number_of_borrowers         0
# debt_to_income_ratio        0
# borrower_credit_score       0
# loan_purpose                0
# insurance_percent           0
# co-borrower_credit_score    0
# insurance_type              0
# m1                          0
# m2                          0
# m3                          0
# m4                          0
# m5                          0
# m6                          0
# m7                          0
# m8                          0
# m9                          0
# m10                         0
# m11                         0
# m12                         0
# m13                         0
# dtype: int64

# %%
data.notnull()
# Out:
#         loan_id  source  financial_institution  interest_rate  \
# 0          True    True                   True           True
# 1          True    True                   True           True
# 2          True    True                   True           True
# 3          True    True                   True           True
# 4          True    True                   True           True
# ...         ...     ...                    ...            ...
# 116053     True    True                   True           True
# 116054     True    True                   True           True
# 116055     True    True                   True           True
# 116056     True    True                   True           True
# 116057     True    True                   True           True
#
#         unpaid_principal_bal  loan_term  origination_date  first_payment_date  \
# 0                       True       True              True                True
# ...

# %%
data.dtypes
# Out:
# loan_id                       int64
# source                       object
# financial_institution        object
# interest_rate               float64
# unpaid_principal_bal          int64
# loan_term                     int64
# origination_date             object
# first_payment_date           object
# loan_to_value                 int64
# number_of_borrowers         float64
# debt_to_income_ratio        float64
# borrower_credit_score       float64
# loan_purpose                 object
# insurance_percent           float64
# co-borrower_credit_score    float64
# insurance_type              float64
# m1                            int64
# m2                            int64
# m3                            int64
# m4                            int64
# m5                            int64
# m6                            int64
# m7                            int64
# m8                            int64
# m9                            int64
# m10                           int64
# ...

# %%
data.fillna(0)
# Out:
#              loan_id source       financial_institution  interest_rate  \
# 0       268055008619      Z  Turner, Baldwin and Rhodes          4.250
# 1       672831657627      Y  Swanson, Newton and Miller          4.875
# 2       742515242108      Z              Thornton-Davis          3.250
# 3       601385667462      X                       OTHER          4.750
# 4       273870029961      X                       OTHER          4.750
# ...              ...    ...                         ...            ...
# 116053  382119962287      Y               Browning-Hart          4.125
# 116054  582803915466      Z                       OTHER          3.000
# 116055  837922316947      X                       OTHER          3.875
# 116056  477343182138      X                       OTHER          4.250
# 116057  763308490661      Z              Thornton-Davis          3.375
#
#         unpaid_principal_bal  loan_term origination_date first_payment_date  \
# ...

# %%
data.drop('interest_rate',axis=1,inplace=True)
data.head()
# Out:
#         loan_id source       financial_institution  unpaid_principal_bal  \
# 0  268055008619      Z  Turner, Baldwin and Rhodes                214000
# 1  672831657627      Y  Swanson, Newton and Miller                144000
# 2  742515242108      Z              Thornton-Davis                366000
# 3  601385667462      X                       OTHER                135000
# 4  273870029961      X                       OTHER                124000
#
#    loan_term origination_date first_payment_date  loan_to_value  \
# 0        360       2012-03-01            05/2012             95
# 1        360       2012-01-01            03/2012             72
# 2        180       2012-01-01            03/2012             49
# 3        360       2012-02-01            04/2012             46
# 4        360       2012-02-01            04/2012             80
#
#    number_of_borrowers  debt_to_income_ratio  ...  m4 m5  m6  m7  m8  m9  m10  \
# ...

# %%
data['source'].unique()
# Out:
# array(['Z', 'Y', 'X'], dtype=object)

# %%
data['source']=data['source'].replace({'x':0,'y':1,'z':2})

# %%
data['source'].unique()
# Out:
# array(['Z', 'Y', 'X'], dtype=object)

# %%
x=data.drop('loan_id',axis=1)
y=data['loan_id']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LRmodel=LogisticRegression()
LRmodel.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2228/61507507.py in <module>
#       1 LRmodel=LogisticRegression()
# ----> 2 LRmodel.fit(x_train,y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...

# %%
data.describe()
# Out:
#             loan_id  unpaid_principal_bal      loan_term  loan_to_value  \
# count  1.160580e+05          1.160580e+05  116058.000000  116058.000000
# mean   5.494155e+11          2.082262e+05     292.280997      67.431939
# std    2.597560e+11          1.146851e+05      89.762415      17.291719
# min    1.000009e+11          1.100000e+04      60.000000       6.000000
# 25%    3.244656e+11          1.200000e+05     180.000000      57.000000
# 50%    5.486239e+11          1.830000e+05     360.000000      72.000000
# 75%    7.743034e+11          2.780000e+05     360.000000      80.000000
# max    9.999971e+11          1.200000e+06     360.000000      97.000000
#
#        number_of_borrowers  debt_to_income_ratio  borrower_credit_score  \
# count        116058.000000         116058.000000          116058.000000
# mean              1.593186             30.742293             769.926778
# std               0.491242              9.730798              42.210706
# ...

# %%
from sklearn.model_selection import KFold

# %%
KFold_validator=KFold(10)

# %%
for train_index,test_index in KFold_validator.split(x,y):
    print('Training Index:',train_index)
    print('Test Index:',test_index)
# Out:
# Training Index: [ 11606  11607  11608 ... 116055 116056 116057]
# Test Index: [    0     1     2 ... 11603 11604 11605]
# Training Index: [     0      1      2 ... 116055 116056 116057]
# Test Index: [11606 11607 11608 ... 23209 23210 23211]
# Training Index: [     0      1      2 ... 116055 116056 116057]
# Test Index: [23212 23213 23214 ... 34815 34816 34817]
# Training Index: [     0      1      2 ... 116055 116056 116057]
# Test Index: [34818 34819 34820 ... 46421 46422 46423]
# Training Index: [     0      1      2 ... 116055 116056 116057]
# Test Index: [46424 46425 46426 ... 58027 58028 58029]
# Training Index: [     0      1      2 ... 116055 116056 116057]
# Test Index: [58030 58031 58032 ... 69633 69634 69635]
# Training Index: [     0      1      2 ... 116055 116056 116057]
# Test Index: [69636 69637 69638 ... 81239 81240 81241]
# Training Index: [     0      1      2 ... 116055 116056 116057]
# Test Index: [81242 81243 81244 ... 92845 92846 92847]
# ...

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score,KFold
from sklearn.linear_model import LogisticRegression

# %%
iris=load_iris()

# %%
x=iris.data
y=iris.data

# %%
LR=LogisticRegression

# %%
K_fold=KFold(n_splits=7)

# %%
score=cross_val_score(LR,x,cv=K_fold)
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     821             try:
# --> 822                 tasks = self._ready_batches.get(block=False)
#     823             except queue.Empty:
#
# C:\ProgramData\Anaconda3\lib\queue.py in get(self, block, timeout)
#     167                 if not self._qsize():
# --> 168                     raise Empty
#     169             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2228/2171062728.py in <module>
# ----> 1 score=cross_val_score(LR,x,cv=K_fold)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
print('cross validation score:'.format(score))
print('avarege cross validation:'.format(score.mean))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2228/1205916906.py in <module>
# ----> 1 print('cross validation score:'.format(score))
#       2 print('avarege cross validation:'.format(score.mean))
#
# NameError: name 'score' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,4))
sns.barplot(x=data["loan_term"],y=data["loan_purpose"])
# Out:
# <AxesSubplot:xlabel='loan_term', ylabel='loan_purpose'>

# %%
y=data['m12']
x=data.drop(columns=['m12'])

# %%
print(x.head())
print(y.head())
# Out:
#         loan_id source       financial_institution  unpaid_principal_bal  \
# 0  268055008619      Z  Turner, Baldwin and Rhodes                214000
# 1  672831657627      Y  Swanson, Newton and Miller                144000
# 2  742515242108      Z              Thornton-Davis                366000
# 3  601385667462      X                       OTHER                135000
# 4  273870029961      X                       OTHER                124000
#
#    loan_term origination_date first_payment_date  loan_to_value  \
# 0        360       2012-03-01            05/2012             95
# 1        360       2012-01-01            03/2012             72
# 2        180       2012-01-01            03/2012             49
# 3        360       2012-02-01            04/2012             46
# 4        360       2012-02-01            04/2012             80
#
#    number_of_borrowers  debt_to_income_ratio  ...  m3 m4  m5  m6  m7  m8  m9  \
# ...

# %%
from sklearn.metrics import mean_squared_error,r2_score
